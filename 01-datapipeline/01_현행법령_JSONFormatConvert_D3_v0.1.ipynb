# %% [markdown]
# # 법률 데이터 JSON Rawdata to D3.js flare structure

# %%
# google.colab 의 drive 라이브러리 이용
from google.colab import drive
drive.mount('/content/gdrive')

# !ls ./gdrive/M* -al
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os

cwd = os.getcwd()
print('Current Working Directory:', cwd)

gdrive = os.path.join(os.getcwd(), 'gdrive', 'My Drive')
print('Check Connection with Google Drive:', gdrive)

dataPath = os.path.join(gdrive, '세미나+스터디', '01_rawdata', '01_rawdata_000001_재외국민등록법_20181102.json')
print('Move to Rawdata Path:', dataPath)
# Out:
# Current Working Directory: /content
# Check Connection with Google Drive: /content/gdrive/My Drive
# Move to Rawdata Path: /content/gdrive/My Drive/세미나+스터디/01_rawdata/01_rawdata_000001_재외국민등록법_20181102.json

# %% [markdown]
# # JSON Structure modifier

# %%
import json
from pprint import pprint

def readJSON(json_file_path):
    
    #법령 JSON 파일을 기준으로 세부 법령 내용 요청
    with open(json_file_path, 'r', encoding="utf-8") as json_data:
        data = json.loads(json_data.read())
    
    return data

# %%
law_json = readJSON(dataPath)

# %%
pprint(law_json)
# Out:
# {'root': {'법령': {'@법령키': '0000012013032311690',
#                  '개정문': {'개정문내용': '⊙법률 제11690호(2013.3.23)\n'
#                                   '\n'
#                                   '\n'
#                                   '정부조직법 전부개정법률\n'
#                                   '\n'
#                                   '\n'
#                                   '\n'
#                                   '\n'
#                                   '\n'
#                                   '\n'
#                                   '[본문 생략]\n'
#                                   '\n'
#                                   '\n'
#                                   '\n'
#                                   '\n'
#                                   '\n'
#                                   '\n'
#                                   '        부칙\n'
#                                   '\n'
#                                   '\n'
#                                   '제1조(시행일) ① 이 법은 공포한 날부터 시행한다. \n'
#                                   '\n'
#                                   '\n'
#                                   '  ② 생략\n'
#                                   '\n'
#                                   '\n'
#                                   '제2조부터 제5조까지 생략\n'
#                                   '\n'
#                                   '\n'
#                                   '제6조(다른 법률의 개정) ①부터 <102>까지 생략\n'
#                                   '\n'
#                                   '\n'
#                                   '  <103> 재외국민등록법 일부를 다음과 같이 개정한다.\n'
#                                   '\n'
#                                   '\n'
#                                   '  제6조 및 제7조제1항 중 "외교통상부장관"을 각각 "외교부장관"으로 '
#                                   '한다.\n'
#                                   '\n'
#                                   '\n'
#                                   '  <104>부터 <710>까지 생략\n'
#                                   '\n'
#                                   '\n'
#                                   '제7조 생략'},
#                  '기본정보': {'공포번호': '11690',
#                           '공포법령여부': 'Y',
#                           '공포일자': '20130323',
#                           '법령ID': '000001',
#                           '법령명_한글': '재외국민등록법',
#                           '법령명_한자': '재외국민등록법',
#                           '법령명약칭': None,
#                           '법종구분': {'#text': '법률', '@법종구분코드': 'A0002'},
#                           '별표편집여부': 'Y',
#                           '소관부처': {'#text': '외교부', '@소관부처코드': '1262000'},
#                           '시행일자': '20130323',
#                           '언어': '한글',
#                           '제개정구분': '타법개정',
#                           '제명변경여부': 'N',
#                           '편장절관': '44040000',
#                           '한글법령여부': 'N'},
#                  '부칙': {'부칙단위': [{'@부칙키': '1999122806057',
#                                   '부칙공포번호': '06057',
#                                   '부칙공포일자': '19991228',
#                                   '부칙내용': '부칙  <제6057호,1999.12.28>\n'
#                                           '\n'
#                                           '\n'
#                                           '①(施行日) 이 법은 공포후 2월이 경과한 날부터 시행한다.\n'
#                                           '\n'
#                                           '\n'
#                                           '②(經過措置) 이 법 시행 당시 종전의 규정에 의하여 '
#                                           '재외국민등록을 한 자는 이 법에 의하여 등록을 한 것으로 '
#                                           '본다.'},
#                                  {'@부칙키': '2007051708435',
#                                   '부칙공포번호': '08435',
#                                   '부칙공포일자': '20070517',
#                                   '부칙내용': '부칙(가족관계의 등록 등에 관한 법률) '
#                                           '<제8435호,2007.5.17>\n'
#                                           '\n'
#                                           '\n'
#                                           '제1조 (시행일) 이 법은 2008년 1월 1일부터 시행한다. '
#                                           '<단서 생략>\n'
#                                           '\n'
#                                           '\n'
#                                           '제2조부터 제7조까지 생략\n'
#                                           '\n'
#                                           '\n'
#                                           '제8조 (다른 법률의 개정) ①부터 <21>까지 생략\n'
#                                           '\n'
#                                           '\n'
#                                           '  <22> 재외국민등록법 일부를 다음과 같이 개정한다.\n'
#                                           '\n'
#                                           '\n'
#                                           '  제3조제4호를 다음과 같이 한다.\n'
#                                           '\n'
#                                           '\n'
#                                           '    4. 등록기준지(가족관계등록이 되어 있는 자의 경우에 '
#                                           '한한다)\n'
#                                           '\n'
#                                           '\n'
#                                           '  <23>부터 <39>까지 생략\n'
#                                           '\n'
#                                           '\n'
#                                           '제9조 생략'},
#                                  {'@부칙키': '2007121408682',
#                                   '부칙공포번호': '08682',
#                                   '부칙공포일자': '20071214',
#                                   '부칙내용': '부칙 <제8682호,2007.12.14>\n'
#                                           '\n'
#                                           '\n'
#                                           '이 법은 공포한 날부터 시행한다.'},
#                                  {'@부칙키': '2013032311690',
#                                   '부칙공포번호': '11690',
#                                   '부칙공포일자': '20130323',
#                                   '부칙내용': '부칙(정부조직법) <제11690호, 2013.3.23>\n'
#                                           '\n'
#                                           '\n'
#                                           '제1조(시행일) ① 이 법은 공포한 날부터 시행한다. \n'
#                                           '\n'
#                                           '\n'
#                                           '  ② 생략\n'
#                                           '\n'
#                                           '\n'
#                                           '제2조부터 제5조까지 생략\n'
#                                           '\n'
#                                           '\n'
#                                           '제6조(다른 법률의 개정) ①부터 <102>까지 생략\n'
#                                           '\n'
#                                           '\n'
#                                           '  <103> 재외국민등록법 일부를 다음과 같이 개정한다.\n'
#                                           '\n'
#                                           '\n'
#                                           '  제6조 및 제7조제1항 중 "외교통상부장관"을 각각 '
#                                           '"외교부장관"으로 한다.\n'
#                                           '\n'
#                                           '\n'
#                                           '  <104>부터 <710>까지 생략\n'
#                                           '\n'
#                                           '\n'
#                                           '제7조 생략'}]},
#                  '제개정이유': {'제개정이유내용': '[전부개정]\n'
#                                       '\n'
#                                       '\n'
#                                       '◇ 개정이유\n'
#                                       '\n'
#                                       '\n'
#                                       '  국가 성장동력의 양대 핵심 축인 과학기술과 정보통신기술을 창조경제의 '
#                                       '원천으로 활용하여 경제부흥을 뒷받침할 수 있도록 정부 조직체계를 '
#                                       '재설계하고, 국민생활 전반에 영향을 미치는 안전 관련 업무 기능을 '
#                                       '강화하여 국민의 안전을 최우선으로 하는 정부를 구현하는 한편, 각 '
#                                       '행정기관 고유의 전문성을 강화하여 행정환경의 변화에 능동적으로 대처할 '
#                                       '수 있도록 하는 등 창조적이고 유능한 정부를 구현할 수 있도록 '
#                                       '정부기능을 재배치하려는 것임.\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '◇ 주요내용\n'
#                                       '\n'
#                                       '\n'
#                                       '  가. 대통령의 국가 위기상황 관리기능을 효과적으로 보좌하기 위하여 '
#                                       '대통령 밑에 국가안보실을 신설함(안 제15조).\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  나. 대통령실ㆍ국무총리실 및 특임장관으로 분산되었던 정무기능 '
#                                       '수행체계를 효율적으로 개편하기 위하여 특임장관을 폐지함.\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  다. 금융위기 등 급변하는 대내외 경제 환경에 체계적으로 대응하기 '
#                                       '위하여 경제분야 정책을 총괄ㆍ조정하는 경제부총리제를 도입함(안 '
#                                       '제19조).\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  라. 국무총리의 정책조정 기능을 강화하여 책임총리제를 뒷받침할 수 '
#                                       '있도록 국무총리실을 국무조정실과 국무총리비서실로 확대ㆍ개편함(안 '
#                                       '제20조 및 제21조).\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  마. 국민생활의 안전을 위하여 식품 및 의약품 안전관리체계를 '
#                                       '국무총리 소속의 식품의약품안전처로 일원화함(안 제25조).\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  바. 과학기술과 정보통신기술 발전을 통하여 일자리를 창출하고, '
#                                       '경제부흥의 기반을 마련할 수 있도록 미래창조과학부를 신설하고, 그 '
#                                       '소관업무를 과학기술정책의 수립ㆍ총괄ㆍ조정ㆍ평가, 과학기술의 '
#                                       '연구개발ㆍ협력ㆍ진흥, 과학기술인력 양성, 원자력 연구ㆍ개발ㆍ생산ㆍ이용, '
#                                       '국가정보화 기획ㆍ정보보호ㆍ정보문화, 방송ㆍ통신의 융합ㆍ진흥 및 '
#                                       '전파관리, 정보통신산업, 우편ㆍ우편환 및 우편대체에 관한 사무로 하며, '
#                                       '교육과학기술부는 교육부로 개편함(안 제28조 및 제29조).\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  사. 통상교섭의 전문성을 강화하고 국내산업의 대외경쟁력을 제고하기 '
#                                       '위하여 외교통상부의 통상교섭 기능을 지식경제부로 이관하고, 그 명칭을 '
#                                       '산업통상자원부로 개편함(안 제30조 및 제37조).\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  아. 국민행복의 필수조건인 국민생활 안전을 책임지는 안전관리 '
#                                       '총괄부처로서의 위상과 기능을 강화하기 위하여 행정안전부를 안전행정부로 '
#                                       '개편함(안 제34조).\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  자. 동북아 해양환경 변화에 능동적으로 대응하고 해양ㆍ항만정책과 '
#                                       '수산정책의 상호 연계를 통해 해양기능의 융합효과를 제고하기 위하여 '
#                                       '해양수산부를 신설하고, 농림수산식품부 및 국토해양부를 각각 '
#                                       '농림축산식품부 및 국토교통부로 개편함(안 제36조ㆍ제42조 및 '
#                                       '제43조).\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '  차. 창의와 혁신을 기반으로 하는 다양한 창조기업의 육성ㆍ지원 '
#                                       '강화를 위하여 중소기업청의 업무영역을 확대함(안 제37조제3항).\n'
#                                       '\n'
#                                       '\n'
#                                       '<법제처 제공>'},
#                  '조문': {'조문단위': [{'@조문키': '0001001',
#                                   '조문내용': '제1조(목적) 이 법은 외국에 거주(居住)하거나 체류(滯留)하는 '
#                                           '대한민국 국민을 등록하도록 하여 재외국민(在外國民)의 현황을 '
#                                           '파악함으로써 재외국민의 국내외 활동의 편익(便益)을 증진하고, '
#                                           '관련 행정 사무를 적절하게 처리하며, 그 밖에 재외국민 '
#                                           '보호정책의 수립에 이바지함을 목적으로 한다.',
#                                   '조문번호': '1',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '목적',
#                                   '조문참고자료': '[전문개정 2007.12.14]'},
#                                  {'@조문키': '0002001',
#                                   '조문내용': '제2조(등록대상) 외국의 일정한 지역에 계속하여 90일 이상 '
#                                           '거주하거나 체류할 의사를 가지고 그 지역에 체류하는 대한민국 '
#                                           '국민은 이 법에 따라 등록하여야 한다.',
#                                   '조문번호': '2',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '등록대상',
#                                   '조문참고자료': '[전문개정 2007.12.14]'},
#                                  {'@조문키': '0003001',
#                                   '조문내용': '제3조(등록공관 및 등록사항) 제2조에 따른 등록을 하려는 '
#                                           '재외국민(이하 "등록대상자"라 한다)은 주소나 거소(居所)를 '
#                                           '관할하는 대한민국 대사관·총영사관·영사관·분관(分館) 또는 '
#                                           '출장소(이하 "등록공관"이라 한다)에 다음 각 호의 사항을 '
#                                           '등록하여야 한다. <개정 2007.5.17>',
#                                   '조문번호': '3',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '등록공관 및 등록사항',
#                                   '조문참고자료': '[전문개정 2007.12.14]',
#                                   '항': {'호': [{'호내용': '1. 성명', '호번호': '1.'},
#                                               {'호내용': '2. 생년월일 및 주민등록번호(국내에서 '
#                                                       '주민등록을 한 자의 경우만 해당한다)',
#                                                '호번호': '2.'},
#                                               {'호내용': '3. 성별', '호번호': '3.'},
#                                               {'호내용': '4. 등록기준지(가족관계등록이 되어 있는 '
#                                                       '자의 경우에 한한다)',
#                                                '호번호': '4.'},
#                                               {'호내용': '5. 직업 및 소속 기관',
#                                                '호번호': '5.'},
#                                               {'호내용': '6. 병역관계(남자의 경우만 해당한다)',
#                                                '호번호': '6.'},
#                                               {'호내용': '7. 체류목적 및 자격',
#                                                '호번호': '7.'},
#                                               {'호내용': '8. 거주국 내의 주소나 거소, 전화번호, '
#                                                       '그 밖의 연락처',
#                                                '호번호': '8.'}]}},
#                                  {'@조문키': '0004001',
#                                   '조문내용': '제4조(등록 기간) 등록대상자는 외국의 일정한 지역에 주소나 '
#                                           '거소를 정한 날부터 30일 이내에 등록공관에 등록하여야 한다.',
#                                   '조문번호': '4',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '등록 기간',
#                                   '조문참고자료': '[전문개정 2007.12.14]'},
#                                  {'@조문키': '0005001',
#                                   '조문내용': '제5조(이중등록 금지) 누구든지 재외국민의 등록을 이중으로 할 '
#                                           '수 없다.',
#                                   '조문번호': '5',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '이중등록 금지',
#                                   '조문참고자료': '[전문개정 2007.12.14]'},
#                                  {'@조문키': '0006001',
#                                   '조문내용': '제6조(재외국민 등록의 관리) 등록공관의 장은 재외국민등록부를 '
#                                           '등록공관에 갖추어 두고, 그 사본을 외교부장관에게 제출하여야 '
#                                           '한다. <개정 2013.3.23>',
#                                   '조문번호': '6',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '재외국민 등록의 관리',
#                                   '조문참고자료': '[전문개정 2007.12.14]'},
#                                  {'@조문키': '0007001',
#                                   '조문내용': '제7조(재외국민등록부 등본)',
#                                   '조문번호': '7',
#                                   '조문변경여부': '1',
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '재외국민등록부 등본',
#                                   '조문참고자료': '[전문개정 2007.12.14]',
#                                   '항': [{'항내용': '① 제4조에 따라 재외공관에 재외국민의 등록을 한 '
#                                                 '자(이하 "등록자"라 한다)는 외교부장관이나 '
#                                                 '등록공관의 장에게 신청하여 재외국민등록부 등본을 '
#                                                 '교부받을 수 있다. <개정 2013.3.23>',
#                                          '항번호': '①',
#                                          '항제개정유형': '개정',
#                                          '항제개정일자문자열': '2013.3.23'},
#                                         {'항내용': '② 재외국민등록부 등본은 등록공관의 장이 '
#                                                 '확인·발급하는 해외 거주 또는 체류 사실 확인서류를 '
#                                                 '갈음할 수 있다.',
#                                          '항번호': '②'}]},
#                                  {'@조문키': '0008001',
#                                   '조문내용': '제8조(변경신고) 등록자는 제3조 각 호의 어느 하나의 '
#                                           '등록사항이 변경되면 변경된 날부터 14일 이내에 변경신고를 '
#                                           '하여야 한다.',
#                                   '조문번호': '8',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '변경신고',
#                                   '조문참고자료': '[전문개정 2007.12.14]'},
#                                  {'@조문키': '0009001',
#                                   '조문내용': '제9조(이동신고)',
#                                   '조문번호': '9',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '이동신고',
#                                   '조문참고자료': '[전문개정 2007.12.14]',
#                                   '항': [{'항내용': '① 등록자가 그 주소나 거소를 변경하여 등록공관을 '
#                                                 '달리하게 되면 제8조에도 불구하고 변경된 날부터 '
#                                                 '30일 이내에 새로운 주소나 거소를 관할하는 '
#                                                 '등록공관의 장(이하 "신주소지 등록공관장"이라 '
#                                                 '한다)에게 이동신고서를 제출하여야 한다.',
#                                          '항번호': '①'},
#                                         {'항내용': '② 신주소지 등록공관장은 제1항에 따른 이동신고서를 '
#                                                 '제출받으면 지체 없이 재외국민등록부 이송요청서에 '
#                                                 '이동신고서 사본을 첨부하여 종전의 주소나 거소를 '
#                                                 '관할하는 등록공관의 장(이하 "구주소지 '
#                                                 '등록공관장"이라 한다)에게 통보하여야 한다.',
#                                          '항번호': '②'},
#                                         {'항내용': '③ 제2항에 따른 통보를 받은 구주소지 등록공관장은 '
#                                                 '재외국민등록부 이송요청서를 받은 날부터 7일 이내에 '
#                                                 '이송(移送)하여야 한다.',
#                                          '항번호': '③'},
#                                         {'항내용': '④ 신주소지 등록공관장은 제3항에 따라 '
#                                                 '재외국민등록부를 이송받으면 제1항에 따른 이동신고서와 '
#                                                 '대조·확인한 후 지체 없이 재외국민등록부를 정리하여야 '
#                                                 '한다.',
#                                          '항번호': '④'}]},
#                                  {'@조문키': '0010001',
#                                   '조문내용': '제10조(전산정보처리조직에 따른 재외국민등록부의 관리) 제3조에 '
#                                           '따른 등록사항을 전산정보처리조직에 따라 처리하는 경우에는 그 '
#                                           '재외국민등록부 파일[자기(磁氣)테이프, 자기디스크, 그 밖에 '
#                                           '이와 비슷한 방법으로 기록·보관하는 것을 말한다]을 제6조에 '
#                                           '따른 재외국민등록부로 본다.',
#                                   '조문번호': '10',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '전산정보처리조직에 따른 재외국민등록부의 관리',
#                                   '조문참고자료': '[전문개정 2007.12.14]'},
#                                  {'@조문키': '0011001',
#                                   '조문내용': '제11조(등록·신고의 방법) 제3조, 제7조제1항, 제8조 및 '
#                                           '제9조에 따른 등록신청, 재외국민등록부 등본 교부신청, 변경신고 '
#                                           '및 이동신고는 대통령령으로 정하는 바에 따라 다음 각 호의 '
#                                           '방법으로 할 수 있다.',
#                                   '조문번호': '11',
#                                   '조문변경여부': None,
#                                   '조문시행일자': '20130323',
#                                   '조문여부': '조문',
#                                   '조문이동이전': '000000',
#                                   '조문이동이후': '000000',
#                                   '조문제개정유형': '전문개정',
#                                   '조문제개정일자문자열': '2007.12.14',
#                                   '조문제목': '등록·신고의 방법',
#                                   '조문참고자료': '[전문개정 2007.12.14]',
#                                   '항': {'호': [{'호내용': '1. 문서', '호번호': '1.'},
#                                               {'호내용': '2. 모사전송(模寫電送)',
#                                                '호번호': '2.'},
#                                               {'호내용': '3. 전자문서', '호번호': '3.'},
#                                               {'호내용': '4. 그 밖의 방법',
#                                                '호번호': '4.'}]}}]}}}}

# %%
print(law_json.keys(), len(law_json))
# Out:
# dict_keys(['root']) 1

# %%
print(law_json['root'].keys(), len(law_json['root'].keys()))
# Out:
# dict_keys(['법령']) 1

# %%
print(law_json['root']['법령'].keys(), len(law_json['root']['법령']))
# Out:
# dict_keys(['@법령키', '기본정보', '조문', '부칙', '개정문', '제개정이유']) 6

# %%
law_json['root']['법령']['@법령키']
# Out:
# '0000012013032311690'

# %%
law_json['root']['법령']['기본정보'].keys()
# Out:
# dict_keys(['법령ID', '공포일자', '공포번호', '언어', '법종구분', '법령명_한글', '법령명_한자', '법령명약칭', '제명변경여부', '한글법령여부', '편장절관', '소관부처', '시행일자', '제개정구분', '별표편집여부', '공포법령여부'])

# %%
law_json['root']['법령']['조문'].keys()
# Out:
# dict_keys(['조문단위'])

# %%
law_json['root']['법령']['조문']['조문단위']
# Out:
# [{'@조문키': '0001001',
#   '조문내용': '제1조(목적) 이 법은 외국에 거주(居住)하거나 체류(滯留)하는 대한민국 국민을 등록하도록 하여 재외국민(在外國民)의 현황을 파악함으로써 재외국민의 국내외 활동의 편익(便益)을 증진하고, 관련 행정 사무를 적절하게 처리하며, 그 밖에 재외국민 보호정책의 수립에 이바지함을 목적으로 한다.',
#   '조문번호': '1',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '목적',
#   '조문참고자료': '[전문개정 2007.12.14]'},
#  {'@조문키': '0002001',
#   '조문내용': '제2조(등록대상) 외국의 일정한 지역에 계속하여 90일 이상 거주하거나 체류할 의사를 가지고 그 지역에 체류하는 대한민국 국민은 이 법에 따라 등록하여야 한다.',
#   '조문번호': '2',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '등록대상',
#   '조문참고자료': '[전문개정 2007.12.14]'},
#  {'@조문키': '0003001',
#   '조문내용': '제3조(등록공관 및 등록사항) 제2조에 따른 등록을 하려는 재외국민(이하 "등록대상자"라 한다)은 주소나 거소(居所)를 관할하는 대한민국 대사관·총영사관·영사관·분관(分館) 또는 출장소(이하 "등록공관"이라 한다)에 다음 각 호의 사항을 등록하여야 한다. <개정 2007.5.17>',
#   '조문번호': '3',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '등록공관 및 등록사항',
#   '조문참고자료': '[전문개정 2007.12.14]',
#   '항': {'호': [{'호내용': '1. 성명', '호번호': '1.'},
#     {'호내용': '2. 생년월일 및 주민등록번호(국내에서 주민등록을 한 자의 경우만 해당한다)', '호번호': '2.'},
#     {'호내용': '3. 성별', '호번호': '3.'},
#     {'호내용': '4. 등록기준지(가족관계등록이 되어 있는 자의 경우에 한한다)', '호번호': '4.'},
#     {'호내용': '5. 직업 및 소속 기관', '호번호': '5.'},
#     {'호내용': '6. 병역관계(남자의 경우만 해당한다)', '호번호': '6.'},
#     {'호내용': '7. 체류목적 및 자격', '호번호': '7.'},
#     {'호내용': '8. 거주국 내의 주소나 거소, 전화번호, 그 밖의 연락처', '호번호': '8.'}]}},
#  {'@조문키': '0004001',
#   '조문내용': '제4조(등록 기간) 등록대상자는 외국의 일정한 지역에 주소나 거소를 정한 날부터 30일 이내에 등록공관에 등록하여야 한다.',
#   '조문번호': '4',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '등록 기간',
#   '조문참고자료': '[전문개정 2007.12.14]'},
#  {'@조문키': '0005001',
#   '조문내용': '제5조(이중등록 금지) 누구든지 재외국민의 등록을 이중으로 할 수 없다.',
#   '조문번호': '5',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '이중등록 금지',
#   '조문참고자료': '[전문개정 2007.12.14]'},
#  {'@조문키': '0006001',
#   '조문내용': '제6조(재외국민 등록의 관리) 등록공관의 장은 재외국민등록부를 등록공관에 갖추어 두고, 그 사본을 외교부장관에게 제출하여야 한다. <개정 2013.3.23>',
#   '조문번호': '6',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '재외국민 등록의 관리',
#   '조문참고자료': '[전문개정 2007.12.14]'},
#  {'@조문키': '0007001',
#   '조문내용': '제7조(재외국민등록부 등본)',
#   '조문번호': '7',
#   '조문변경여부': '1',
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '재외국민등록부 등본',
#   '조문참고자료': '[전문개정 2007.12.14]',
#   '항': [{'항내용': '① 제4조에 따라 재외공관에 재외국민의 등록을 한 자(이하 "등록자"라 한다)는 외교부장관이나 등록공관의 장에게 신청하여 재외국민등록부 등본을 교부받을 수 있다. <개정 2013.3.23>',
#     '항번호': '①',
#     '항제개정유형': '개정',
#     '항제개정일자문자열': '2013.3.23'},
#    {'항내용': '② 재외국민등록부 등본은 등록공관의 장이 확인·발급하는 해외 거주 또는 체류 사실 확인서류를 갈음할 수 있다.',
#     '항번호': '②'}]},
#  {'@조문키': '0008001',
#   '조문내용': '제8조(변경신고) 등록자는 제3조 각 호의 어느 하나의 등록사항이 변경되면 변경된 날부터 14일 이내에 변경신고를 하여야 한다.',
#   '조문번호': '8',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '변경신고',
#   '조문참고자료': '[전문개정 2007.12.14]'},
#  {'@조문키': '0009001',
#   '조문내용': '제9조(이동신고)',
#   '조문번호': '9',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '이동신고',
#   '조문참고자료': '[전문개정 2007.12.14]',
#   '항': [{'항내용': '① 등록자가 그 주소나 거소를 변경하여 등록공관을 달리하게 되면 제8조에도 불구하고 변경된 날부터 30일 이내에 새로운 주소나 거소를 관할하는 등록공관의 장(이하 "신주소지 등록공관장"이라 한다)에게 이동신고서를 제출하여야 한다.',
#     '항번호': '①'},
#    {'항내용': '② 신주소지 등록공관장은 제1항에 따른 이동신고서를 제출받으면 지체 없이 재외국민등록부 이송요청서에 이동신고서 사본을 첨부하여 종전의 주소나 거소를 관할하는 등록공관의 장(이하 "구주소지 등록공관장"이라 한다)에게 통보하여야 한다.',
#     '항번호': '②'},
#    {'항내용': '③ 제2항에 따른 통보를 받은 구주소지 등록공관장은 재외국민등록부 이송요청서를 받은 날부터 7일 이내에 이송(移送)하여야 한다.',
#     '항번호': '③'},
#    {'항내용': '④ 신주소지 등록공관장은 제3항에 따라 재외국민등록부를 이송받으면 제1항에 따른 이동신고서와 대조·확인한 후 지체 없이 재외국민등록부를 정리하여야 한다.',
#     '항번호': '④'}]},
#  {'@조문키': '0010001',
#   '조문내용': '제10조(전산정보처리조직에 따른 재외국민등록부의 관리) 제3조에 따른 등록사항을 전산정보처리조직에 따라 처리하는 경우에는 그 재외국민등록부 파일[자기(磁氣)테이프, 자기디스크, 그 밖에 이와 비슷한 방법으로 기록·보관하는 것을 말한다]을 제6조에 따른 재외국민등록부로 본다.',
#   '조문번호': '10',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '전산정보처리조직에 따른 재외국민등록부의 관리',
#   '조문참고자료': '[전문개정 2007.12.14]'},
#  {'@조문키': '0011001',
#   '조문내용': '제11조(등록·신고의 방법) 제3조, 제7조제1항, 제8조 및 제9조에 따른 등록신청, 재외국민등록부 등본 교부신청, 변경신고 및 이동신고는 대통령령으로 정하는 바에 따라 다음 각 호의 방법으로 할 수 있다.',
#   '조문번호': '11',
#   '조문변경여부': None,
#   '조문시행일자': '20130323',
#   '조문여부': '조문',
#   '조문이동이전': '000000',
#   '조문이동이후': '000000',
#   '조문제개정유형': '전문개정',
#   '조문제개정일자문자열': '2007.12.14',
#   '조문제목': '등록·신고의 방법',
#   '조문참고자료': '[전문개정 2007.12.14]',
#   '항': {'호': [{'호내용': '1. 문서', '호번호': '1.'},
#     {'호내용': '2. 모사전송(模寫電送)', '호번호': '2.'},
#     {'호내용': '3. 전자문서', '호번호': '3.'},
#     {'호내용': '4. 그 밖의 방법', '호번호': '4.'}]}}]

# %%
def recursiveJsonDataConversion(jsonData):

    d3_json = []

    if type(jsonData) == dict:
        keys = jsonData.keys()
        for key in keys:
            d3_json.append({
                'name': key,
                'children': recursiveJsonDataConversion(jsonData[key])
            })

    elif type(jsonData) == list:
        temp = []
        i = 1
        for item in jsonData:
            temp.append({
                'name': f'item_%03d' % i,
                'children':recursiveJsonDataConversion(item)
            })
            i += 1
        return temp
    
    elif type(jsonData) == str:
        return [{'name':jsonData}]
    
    return d3_json

# %%
aa = recursiveJsonDataConversion(law_json)[0]

# %%
savePath = os.path.join(gdrive, '세미나+스터디')

with open(f'{savePath}/test.json', 'w', encoding='utf-8') as f:
    json.dump(aa, f)

# %%
with open(f'{savePath}/test.json', 'r', encoding='utf-8') as f:
    bb = json.load(f)
